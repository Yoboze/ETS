# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the dataset
file_path = 'New_cleaned_dataset.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
data.head()
# Out:
#     user_id   order_id                   submit_datetime  skuid  \
# 0  13F987F6  137957563  2024-02-18 10:52:30.097000+00:00   6051
# 1  13F98A7A  137890605  2024-02-01 18:56:06.108000+00:00   6051
# 2  13F98AHC  137931243  2024-02-11 23:20:58.192000+00:00   6051
# 3  13F98B34  137891021  2024-02-01 21:47:37.347000+00:00   4053
# 4  13F98E1G  138070120  2024-03-13 16:43:57.363000+00:00   6042
#
#    profile_created_time  profile_created_time_sec  order_sumitted  \
# 0      1706787989822000              1.706788e+09    1.708254e+09
# 1      1706812320800000              1.706812e+09    1.706814e+09
# 2      1706819691211000              1.706820e+09    1.707694e+09
# 3      1706822375070000              1.706822e+09    1.706824e+09
# 4      1706868798495000              1.706869e+09    1.710348e+09
#
#    time_diff_sec COUNTRY   AGE  ...  view_feedback_count  view_plan_count  \
# 0    1465560.275  Others  15.0  ...                  3.0              0.0
# ...

# %%
# Convert boolean columns for country groups to 0 and 1
boolean_columns = [
    'COUNTRY_GROUPED_DE', 'COUNTRY_GROUPED_FR', 'COUNTRY_GROUPED_IN',
    'COUNTRY_GROUPED_Others', 'COUNTRY_GROUPED_US'
]

for col in boolean_columns:
    data[col] = data[col].astype(int)

# Display the first few rows to verify the changes
data[boolean_columns].head()
# Out:
#    COUNTRY_GROUPED_DE  COUNTRY_GROUPED_FR  COUNTRY_GROUPED_IN  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0
#
#    COUNTRY_GROUPED_Others  COUNTRY_GROUPED_US
# 0                       1                   0
# 1                       1                   0
# 2                       0                   1
# 3                       1                   0
# 4                       1                   0

# %%
# Ensure the dataset retains its original column count of 24 columns
# Check the current number of columns
initial_columns = data.columns.tolist()

# Convert boolean columns to 0 and 1
for col in boolean_columns:
    data[col] = data[col].astype(int)

# Ensure the dataset retains the same number of columns
current_columns = data.columns.tolist()

# Check if any columns have been added or removed
if len(initial_columns) != len(current_columns):
    raise ValueError("Column count has changed during processing.")

# Display the first few rows to verify the changes
data.head()
# Out:
#     user_id   order_id                   submit_datetime  skuid  \
# 0  13F987F6  137957563  2024-02-18 10:52:30.097000+00:00   6051
# 1  13F98A7A  137890605  2024-02-01 18:56:06.108000+00:00   6051
# 2  13F98AHC  137931243  2024-02-11 23:20:58.192000+00:00   6051
# 3  13F98B34  137891021  2024-02-01 21:47:37.347000+00:00   4053
# 4  13F98E1G  138070120  2024-03-13 16:43:57.363000+00:00   6042
#
#    profile_created_time  profile_created_time_sec  order_sumitted  \
# 0      1706787989822000              1.706788e+09    1.708254e+09
# 1      1706812320800000              1.706812e+09    1.706814e+09
# 2      1706819691211000              1.706820e+09    1.707694e+09
# 3      1706822375070000              1.706822e+09    1.706824e+09
# 4      1706868798495000              1.706869e+09    1.710348e+09
#
#    time_diff_sec COUNTRY   AGE  ...  view_feedback_count  view_plan_count  \
# 0    1465560.275  Others  15.0  ...                  3.0              0.0
# ...

# %%
# Save the updated dataset to a new CSV file
updated_file_path = 'Updated_New_cleaned_dataset.csv'
data.to_csv(updated_file_path, index=False)

updated_file_path
# Out:
# 'Updated_New_cleaned_dataset.csv'
